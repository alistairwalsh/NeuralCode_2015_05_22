# %% [markdown]
# #patient data

# %% [markdown]
#     Talitha has been collecting participant data in an excel spreadsheet. It might be possible to make a python participant class that makes this information more useful.
#
# ---
#
#     We can use the class key word to create a class called Participant (with a capital 'P')

# %%
class Participant():
    '''
    Collects patient data.
    '''
    def __init__(self, id_number):
        self.id_number=id_number

# %% [markdown]
#     The 'self' notation is a little hard to explain so I won't.

# %%
participant_1 = Participant(1)

# %%
participant_1.id_number
# Out:
# 1

# %% [markdown]
#     We can create as many participants as we like. They all contain their own information.

# %%
participant_2 = Participant(2,'male',36)

# %%
participant_2.id_number
# Out:
# 2

# %% [markdown]
#     Let's add a bit more functionality to our class and put in some testing to make our data cleaner

# %%
class Participant():
    '''
    Collects patient data.
    '''
    def __init__(self, id_number, sex, age):
        
        sex=sex.lower()
        
        self.id_number=id_number
        self.sex=sex
        self.age=age
        
        assert type(self.id_number) is int, "id_number - '{}' is not an integer".format(id_number)
        assert type(self.age) is int, "age - '{}' is not an integer".format(age)
        assert self.age < 100 and self.age > 0, "age - {} is not < 100 and > 0 ".format(age)
        
        assert type(self.sex) is str, "sex value - '{}' is not a string".format(sex)
        assert self.sex=='male' or sex=='female', "sex - '{}' is not either 'male' or 'female'".format(sex)

# %%
# if the age of the participant is not < 100 and not > 0, an error occurs
participant_3 = Participant(3,'Female',-3)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-302-20783762a923> in <module>()
#       1 # if the age of the participant is not < 100 and not > 0, an error occurs
# ----> 2 participant_3 = Participant(3,'Female',-3)
#
# <ipython-input-300-9e0dd325d290> in __init__(self, id_number, sex, age)
#      13         assert type(self.id_number) is int, "id_number - '{}' is not an integer".format(id_number)
#      14         assert type(self.age) is int, "age - '{}' is not an integer".format(age)
# ---> 15         assert self.age < 100 and self.age > 0, "age - {} is not < 100 and > 0 ".format(age)
#      16
#      17         assert type(self.sex) is str, "sex value - '{}' is not a string".format(sex)
#
# AssertionError: age - -3 is not < 100 and > 0

# %%
#if the age is not an integer, an error occurs
participant_3 = Participant('two','Female',27)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-298-1e6ad20daf35> in <module>()
#       1 #if the age is not an integer, an error occurs
# ----> 2 participant_3 = Participant('two','Female',27)
#
# <ipython-input-295-ec93d483589f> in __init__(self, id_number, sex, age)
#      11         self.age=age
#      12
# ---> 13         assert type(self.id_number) is int, "id_number - '{}' is not an integer".format(id_number)
#      14         assert type(self.age) is int, "age - '{}' is not an integer".format(age)
#      15         assert self.age > 100 and self.age < 0, "age - {} is not < 100 and > 0 ".format(age)
#
# AssertionError: id_number - 'two' is not an integer

# %%
#If sex is not stated as a full word, an error occurs
participant_3 = Participant(3,'F',27)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-303-d88b98d253f7> in <module>()
#       1 #If sex is not stated as a full word, an error occurs
# ----> 2 participant_3 = Participant(3,'F',27)
#
# <ipython-input-300-9e0dd325d290> in __init__(self, id_number, sex, age)
#      16
#      17         assert type(self.sex) is str, "sex value - '{}' is not a string".format(sex)
# ---> 18         assert self.sex=='male' or sex=='female', "sex - '{}' is not either 'male' or 'female'".format(sex)
#
# AssertionError: sex - 'f' is not either 'male' or 'female'

# %% [markdown]
# ---

# %% [markdown]
#     For a simple example of how our class can have functionality as well, lets calculate summary data

# %%
class Participant():
    '''
    Collects patient data.
    '''
    import numpy as np
    
    def __init__(self, id_number, sex, age, test_scores):
        
        sex=sex.lower()
        
        self.id_number=id_number
        self.sex=sex
        self.age=age
        self.test_scores=test_scores
        
        
        assert type(self.id_number) is int, "id_number - '{}' is not an integer".format(id_number)
        assert type(self.age) is int, "age - '{}' is not an integer".format(age)
        assert self.age < 100 and self.age > 0, "age - {} is not < 100 and > 0 ".format(age)
        
        assert type(self.sex) is str, "sex value - '{}' is not a string".format(sex)
        assert self.sex=='male' or sex=='female', "sex - '{}' is not either 'male' or 'female'".format(sex)
        
        assert type(self.test_scores) is list, "test_scores - '{}' is not a list".format(test_scores)
        
    
    def average_score(self):
        return np.average(self.test_scores)

# %%
#so now individual test scores can be added
participant_4 = Participant(4,'Male',19,[67,44,38,94,99,30])

# %%
print("Participant {}'s individual test scores were {} for an average score of {}".format(participant_4.id_number,
                                                                                          participant_4.test_scores,
                                                                                          participant_4.average_score()
                                                                                         )
     )
# Out:
# Participant 4's individual test scores were [67, 44, 38, 94, 99, 30] for an average score of 62.0

# %% [markdown]
#     Using the real data

# %%
import pandas as pd

# %%
#using the ID column of the data as the unique id
df = pd.read_excel('Phase2_ParticipantInfo.xlsx',skiprows= 2,index_col = 0)
#remove the rows with NaN's
df = df.drop(['Low','High'],axis=0)

# %%
#Not a thorough fix but a quick tidy up of column names
df.columns = [x.replace(' ','_') for x in df.columns]

# %%
df
# Out:
#       Age  Gender  Years Educ          Education Comp  \
# ID
#  8     26  Female         6.0           Undergraduate
#  31    26       F         3.5          Secondary/TAFE
#  56    27    Male        13.0           Post Graduate
#  140   19       F         2.0               Secondary
#  148   19       M         2.0           Undergraduate
#  185   18       F         3.0               Secondary
#  176   18  Female         3.0               Secondary
#  227   19       F         3.0               Secondary
#  233   18       F         3.0               Secondary
#  279   33    Male        20.0           Post Graduate
#  318   20  Female         3.0               Secondary
#  378   19  Female         3.0               Secondary
#  505   27  Female         7.0           Undergraduate
#  506   25  Female        20.0           Undergraduate
#  570   26  Female        17.0                Graduate
#  619   30  Female         7.0           Undergraduate
# NaN   NaN     NaN         NaN                     NaN
#  35    37  Female        15.0                Graduate
#  55    20    Male         4.0               Secondary
#  106   18  Female        14.0               Secondary
#  139   18       M         3.0               Secondary
#  141   18       F         2.5               Secondary
#  166   19  Female         3.0               Secondary
#  274   27    Male        12.0                Graduate
#  286   18  Female         2.0               Secondary
#  394   18  Female         3.0               Secondary
#  518   22  Female         7.0               Secondary
#  580   29  Female         9.0  Undergraduate, Honours
#
#                         Study disapline                        Occupation  \
# ID
#  8                Nutrition & Dietetics                 Dietician/Teacher
#  31               International studies                       Electrician
#  56                    Medical Research                   Research Fellow
#  140                 Psych and Forensic                           Student
#  148                         psychology                           student
#  185                         Psychology                           Butcher
#  176  Business (advertising)/Psychology                           Student
#  227                Forensic Psychology       Student & part time watress
#  233                         Psychology                        unemployed
#  279                   hearing research                       audiologist
#  318        Psychology Forensic Science                           Student
#  378                         Psychology                      Receptionist
#  505                     neuro science                           Student
#  506                         Psychology                           Student
#  570                         psychology                           student
#  619        Human Resources & Education               HR Projects Officer
# NaN                                 NaN                               NaN
#  35                Sensory neuroscience                        Researcher
#  55   International & Political studies                           Student
#  106                         Philosophy                           Student
#  139                Science(Psychology)                            Studen
#  141                 Psych and Forensic                           Student
#  166                        Psychology                           Student
#  274                                 IT  PhD Student / Software Developer
#  286   Criminology and Forensic Science                           Student
#  394        Psychology/forensic science                           cinemas
#  518                   Psychophysiology                 Medical Scientist
#  580             Cognitive Neuroscience              Student / Researcher
#
#      Hearing Medication                              Unnamed: 9  \
# ID
#  8       No.        No.                                     NaN
#  31       no         no                                     NaN
#  56      No.        yes                                  zertex
#  140      No         No                                     NaN
#  148     No.         no                                     NaN
#  185     No.         No                                     NaN
#  176     No.       Yes.  The Pill, Ventolin as needed, Seritide
#  227     No.        Yes                     Pill(Levlin), xyzal
#  233     No.         No                                     NaN
#  279     No.        No.                                     NaN
#  318     No.        No.                                     NaN
#  378     No.        Yes                                   Pill
#  505     No.        No.                                     NaN
#  506     No.       Yes.                           Contraceptive
#  570     No.        No.                                     NaN
#  619     No.        No.                                     NaN
# NaN      NaN        NaN                                     NaN
#  35      No.        No.                                     NaN
#  55      No.        No.                                     NaN
#  106     No.        Yes                                    Pill
#  139      no         no                                     NaN
#  141      no         no                                     NaN
#  166     No.        No.                         Pill(Femme tab)
#  274     No.        No.                                     NaN
#  286     No.        No.                                     NaN
#  394     No.        No.                                     NaN
#  518     No.        No.                                     NaN
#  580     No.        No.                                     NaN
#
#      General Fam history?                                        Unnamed: 11  \
# ID
#  8                   Yes.      Grandfather had Seasonal Affective Depression
#  31                    No                                                NaN
#  56                    No                                                NaN
#  140                  NaN                                                NaN
#  148                  Yes                                      Aunty Anxiety
#  185                  NaN                                                NaN
#  176                  Yes                          Schizophrenia, Depression
#  227                   No                                                NaN
#  233                  Yes                           Depression, bipolar, ASD
#  279                  No.                                                NaN
#  318                  No.                                                NaN
#  378                  Yes                                         Depression
#  505                 Yes.                 Depression, Schizophrenia, Anxiety
#  506                  No.                                                NaN
#  570                 Yes.                             Bipolar, schizophrenia
#  619                  Yes                                                NaN
# NaN                   NaN                                                NaN
#  35                  Yes.                          Paternal Major Depression
#  55                  Yes.  Mother's cousin on her father's side was diagn...
#  106                  Yes                                       Schizophenia
#  139                  NaN                                                NaN
#  141                  NaN                                                NaN
#  166                  Yes                                         Depression
#  274                   No                                                NaN
#  286                  Yes                                 Male cousin Autism
#  394                 Yes.                          Brother is schizophrenic
#  518                  No.                                                NaN
#  580                  No.                                                NaN
#
#      1st degree Family history  \
# ID
#  8                          No
#  31                        yes
#  56                        No.
#  140                        No
#  148                        No
#  185                        No
#  176                       No.
#  227                        No
#  233                      Yes.
#  279                        No
#  318                        No
#  378                       Yes
#  505                       Yes
#  506                        No
#  570                       Yes
#  619                      Yes.
# NaN                        NaN
#  35                       Yes.
#  55                        NaN
#  106                      Yes.
#  139                       yes
#  141                        no
#  166                        No
#  274                        No
#  286                     Check
#  394                       NaN
#  518                       NaN
#  580                       NaN
#
#                                             Diagnosis Personal History  \
# ID
#  8                                                NaN               No
#  31                              Paternal cyclothymia               No
#  56                                               NaN              NaN
#  140                                              NaN               No
#  148                                              NaN               No
#  185                                              NaN              NA?
#  176                                              NaN               No
#  227                                              NaN               No
#  233                Maternal and Paternal Depression               Yes
#  279                                              NaN               No
#  318                                              NaN              No.
#  378          Maternal Depression, Sibling Depression               No
#  505                 Mother Depression, Schizophrenia               No
#  506                                              NaN               No
#  570                                  Sibling Bipolar               No
#  619  brother ASD as adult, schizophrenia, depression               No
# NaN                                               NaN              NaN
#  35                         Paternal Major Depression              Yes
#  55                                               NaN              NaN
#  106                           Paternal Schizophrenia              Yes
#  139                              Maternal depression              NaN
#  141                                              NaN              NaN
#  166                                              NaN               No
#  274                                              NaN               No
#  286                                              NaN              Yes
#  394                                              NaN              NaN
#  518                                              NaN              NaN
#  580                                              NaN              NaN
#
#                                             Diagnosis.1  \
# ID
#  8                                                  NaN
#  31                                                 NaN
#  56                                                 NaN
#  140                                                NaN
#  148                                                NaN
#  185                                                NaN
#  176                                                NaN
#  227                                                NaN
#  233                                         Depression
#  279                                                NaN
#  318                                                NaN
#  378                                                NaN
#  505                                                NaN
#  506                                                NaN
#  570                                                NaN
#  619                                                NaN
# NaN                                                 NaN
#  35   Bipolar affective disorder(type 1)with psychot...
#  55                                                 NaN
#  106                                           Anorexia
#  139                                                NaN
#  141                                                NaN
#  166                                                NaN
#  274                                                NaN
#  286                                 Deression, Anxiety
#  394                                                NaN
#  518                                                NaN
#  580                                                NaN
#
#                   Medicated?  Smoker?  Frequency    Menstruation  \
# ID
#  8                        No       No        NaN               -
#  31                      NaN       No        NaN             NaN
#  56                      NaN       No        NaN             NaN
#  140                     NaN      NaN        NaN             NaN
#  148                     NaN  CONTACT        NaN             NaN
#  185                     NaN      NaN        NaN             NaN
#  176                     NaN       No        NaN         21 days
#  227                     NaN  CONTACT        NaN             NaN
#  233                      No  CONTACT        NaN             NaN
#  279                     NaN       No        NaN             NaN
#  318                     NaN       No        NaN           4days
#  378                     NaN       No        NaN          8 days
#  505                     NaN       No        NaN          1month
#  506                     NaN       No        NaN  Unknown(years)
#  570                     NaN       No        NaN          14days
#  619                     NaN       No        NaN           0days
# NaN                      NaN      NaN        NaN             NaN
#  35                      Yes       No        NaN             NaN
#  55                      NaN      NaN        NaN             NaN
#  106                     No        No        NaN           7days
#  139                     NaN      NaN        NaN             NaN
#  141                     NaN      NaN        NaN             NaN
#  166                     NaN       No        NaN          14days
#  274                     NaN       No        NaN             NaN
#  286  Yes(Zoloft sertraline)       No        NaN         5 weeks
#  394                     NaN      NaN        NaN             NaN
#  518                     NaN      NaN        NaN             NaN
#  580                     NaN       No        NaN          5 days
#
#              Contraceptive
# ID
#  8                     NaN
#  31                    NaN
#  56                    NaN
#  140                   NaN
#  148                   NaN
#  185                   NaN
#  176       Yes, Pill (Jaz)
#  227      Yes,Pill(Levlin)
#  233             yes, pill
#  279                   NaN
#  318                    No
#  378           Yes, Levlin
#  505             Yes, Pill
#  506    Yes, Depo Ralovera
#  570                    No
#  619                    No
# NaN                    NaN
#  35            Yes, Merina
#  55                    NaN
#  106             yes, pill
#  139                   NaN
#  141                   NaN
#  166  Yes, Pill(femme tab)
#  274                   NaN
#  286                    no
#  394                   NaN
#  518                   NaN
#  580                    No

# %%
#finally remove the NaN row
df = df.dropna(axis = 0,how = 'all')
#and change the column names to something more useable
df.columns = [x.replace(' ','_') for x in df.columns]
print(df)
# Out:
#      Age  Gender  Years_Educ          Education_Comp  \
# ID
# 8     26  female         6.0           Undergraduate
# 31    26  female         3.5          Secondary/TAFE
# 56    27    male        13.0           Post Graduate
# 140   19  female         2.0               Secondary
# 148   19    male         2.0           Undergraduate
# 185   18  female         3.0               Secondary
# 176   18  female         3.0               Secondary
# 227   19  female         3.0               Secondary
# 233   18  female         3.0               Secondary
# 279   33    male        20.0           Post Graduate
# 318   20  female         3.0               Secondary
# 378   19  female         3.0               Secondary
# 505   27  female         7.0           Undergraduate
# 506   25  female        20.0           Undergraduate
# 570   26  female        17.0                Graduate
# 619   30  female         7.0           Undergraduate
# 35    37  female        15.0                Graduate
# 55    20    male         4.0               Secondary
# 106   18  female        14.0               Secondary
# 139   18    male         3.0               Secondary
# 141   18  female         2.5               Secondary
# 166   19  female         3.0               Secondary
# 274   27    male        12.0                Graduate
# 286   18  female         2.0               Secondary
# 394   18  female         3.0               Secondary
# 518   22  female         7.0               Secondary
# 580   29  female         9.0  Undergraduate, Honours
#
#                        Study_disapline                        Occupation  \
# ID
# 8                Nutrition & Dietetics                 Dietician/Teacher
# 31               International studies                       Electrician
# 56                    Medical Research                   Research Fellow
# 140                 Psych and Forensic                           Student
# 148                         psychology                           student
# 185                         Psychology                           Butcher
# 176  Business (advertising)/Psychology                           Student
# 227                Forensic Psychology       Student & part time watress
# 233                         Psychology                        unemployed
# 279                   hearing research                       audiologist
# 318        Psychology Forensic Science                           Student
# 378                         Psychology                      Receptionist
# 505                     neuro science                           Student
# 506                         Psychology                           Student
# 570                         psychology                           student
# 619        Human Resources & Education               HR Projects Officer
# 35                Sensory neuroscience                        Researcher
# 55   International & Political studies                           Student
# 106                         Philosophy                           Student
# 139                Science(Psychology)                            Studen
# 141                 Psych and Forensic                           Student
# 166                        Psychology                           Student
# 274                                 IT  PhD Student / Software Developer
# 286   Criminology and Forensic Science                           Student
# 394        Psychology/forensic science                           cinemas
# 518                   Psychophysiology                 Medical Scientist
# 580             Cognitive Neuroscience              Student / Researcher
#
#     Hearing Medication                              Unnamed:_9  \
# ID
# 8        no         no                                     NaN
# 31       no         no                                     NaN
# 56       no        yes                                  zertex
# 140      no         no                                     NaN
# 148      no         no                                     NaN
# 185      no         no                                     NaN
# 176      no        yes  The Pill, Ventolin as needed, Seritide
# 227      no        yes                     Pill(Levlin), xyzal
# 233      no         no                                     NaN
# 279      no         no                                     NaN
# 318      no         no                                     NaN
# 378      no        yes                                   Pill
# 505      no         no                                     NaN
# 506      no        yes                           Contraceptive
# 570      no         no                                     NaN
# 619      no         no                                     NaN
# 35       no         no                                     NaN
# 55       no         no                                     NaN
# 106      no        yes                                    Pill
# 139      no         no                                     NaN
# 141      no         no                                     NaN
# 166      no         no                         Pill(Femme tab)
# 274      no         no                                     NaN
# 286      no         no                                     NaN
# 394      no         no                                     NaN
# 518      no         no                                     NaN
# 580      no         no                                     NaN
#
#     General_Fam_history?                                        Unnamed:_11  \
# ID
# 8                   Yes.      Grandfather had Seasonal Affective Depression
# 31                    No                                                NaN
# 56                    No                                                NaN
# 140                  NaN                                                NaN
# 148                  Yes                                      Aunty Anxiety
# 185                  NaN                                                NaN
# 176                  Yes                          Schizophrenia, Depression
# 227                   No                                                NaN
# 233                  Yes                           Depression, bipolar, ASD
# 279                  No.                                                NaN
# 318                  No.                                                NaN
# 378                  Yes                                         Depression
# 505                 Yes.                 Depression, Schizophrenia, Anxiety
# 506                  No.                                                NaN
# 570                 Yes.                             Bipolar, schizophrenia
# 619                  Yes                                                NaN
# 35                  Yes.                          Paternal Major Depression
# 55                  Yes.  Mother's cousin on her father's side was diagn...
# 106                  Yes                                       Schizophenia
# 139                  NaN                                                NaN
# 141                  NaN                                                NaN
# 166                  Yes                                         Depression
# 274                   No                                                NaN
# 286                  Yes                                 Male cousin Autism
# 394                 Yes.                          Brother is schizophrenic
# 518                  No.                                                NaN
# 580                  No.                                                NaN
#
#     1st_degree_Family_history  \
# ID
# 8                          No
# 31                        yes
# 56                        No.
# 140                        No
# 148                        No
# 185                        No
# 176                       No.
# 227                        No
# 233                      Yes.
# 279                        No
# 318                        No
# 378                       Yes
# 505                       Yes
# 506                        No
# 570                       Yes
# 619                      Yes.
# 35                       Yes.
# 55                        NaN
# 106                      Yes.
# 139                       yes
# 141                        no
# 166                        No
# 274                        No
# 286                     Check
# 394                       NaN
# 518                       NaN
# 580                       NaN
#
#                                            Diagnosis Personal_History  \
# ID
# 8                                                NaN               No
# 31                              Paternal cyclothymia               No
# 56                                               NaN              NaN
# 140                                              NaN               No
# 148                                              NaN               No
# 185                                              NaN              NA?
# 176                                              NaN               No
# 227                                              NaN               No
# 233                Maternal and Paternal Depression               Yes
# 279                                              NaN               No
# 318                                              NaN              No.
# 378          Maternal Depression, Sibling Depression               No
# 505                 Mother Depression, Schizophrenia               No
# 506                                              NaN               No
# 570                                  Sibling Bipolar               No
# 619  brother ASD as adult, schizophrenia, depression               No
# 35                         Paternal Major Depression              Yes
# 55                                               NaN              NaN
# 106                           Paternal Schizophrenia              Yes
# 139                              Maternal depression              NaN
# 141                                              NaN              NaN
# 166                                              NaN               No
# 274                                              NaN               No
# 286                                              NaN              Yes
# 394                                              NaN              NaN
# 518                                              NaN              NaN
# 580                                              NaN              NaN
#
#                                            Diagnosis.1  \
# ID
# 8                                                  NaN
# 31                                                 NaN
# 56                                                 NaN
# 140                                                NaN
# 148                                                NaN
# 185                                                NaN
# 176                                                NaN
# 227                                                NaN
# 233                                         Depression
# 279                                                NaN
# 318                                                NaN
# 378                                                NaN
# 505                                                NaN
# 506                                                NaN
# 570                                                NaN
# 619                                                NaN
# 35   Bipolar affective disorder(type 1)with psychot...
# 55                                                 NaN
# 106                                           Anorexia
# 139                                                NaN
# 141                                                NaN
# 166                                                NaN
# 274                                                NaN
# 286                                 Deression, Anxiety
# 394                                                NaN
# 518                                                NaN
# 580                                                NaN
#
#                  Medicated?  Smoker?  Frequency    Menstruation  \
# ID
# 8                        No       No        NaN               -
# 31                      NaN       No        NaN             NaN
# 56                      NaN       No        NaN             NaN
# 140                     NaN      NaN        NaN             NaN
# 148                     NaN  CONTACT        NaN             NaN
# 185                     NaN      NaN        NaN             NaN
# 176                     NaN       No        NaN         21 days
# 227                     NaN  CONTACT        NaN             NaN
# 233                      No  CONTACT        NaN             NaN
# 279                     NaN       No        NaN             NaN
# 318                     NaN       No        NaN           4days
# 378                     NaN       No        NaN          8 days
# 505                     NaN       No        NaN          1month
# 506                     NaN       No        NaN  Unknown(years)
# 570                     NaN       No        NaN          14days
# 619                     NaN       No        NaN           0days
# 35                      Yes       No        NaN             NaN
# 55                      NaN      NaN        NaN             NaN
# 106                     No        No        NaN           7days
# 139                     NaN      NaN        NaN             NaN
# 141                     NaN      NaN        NaN             NaN
# 166                     NaN       No        NaN          14days
# 274                     NaN       No        NaN             NaN
# 286  Yes(Zoloft sertraline)       No        NaN         5 weeks
# 394                     NaN      NaN        NaN             NaN
# 518                     NaN      NaN        NaN             NaN
# 580                     NaN       No        NaN          5 days
#
#             Contraceptive
# ID
# 8                     NaN
# 31                    NaN
# 56                    NaN
# 140                   NaN
# 148                   NaN
# 185                   NaN
# 176       Yes, Pill (Jaz)
# 227      Yes,Pill(Levlin)
# 233             yes, pill
# 279                   NaN
# 318                    No
# 378           Yes, Levlin
# 505             Yes, Pill
# 506    Yes, Depo Ralovera
# 570                    No
# 619                    No
# 35            Yes, Merina
# 55                    NaN
# 106             yes, pill
# 139                   NaN
# 141                   NaN
# 166  Yes, Pill(femme tab)
# 274                   NaN
# 286                    no
# 394                   NaN
# 518                   NaN
# 580                    No

# %% [markdown]
#     The list comprehension probably deserves an explanation.
#     for every entry in the Gender column,
#     - the value is converted to lowercase
#     - the 0th letter is passed to the next function
#     - 'm' is changed to 'male'
#     - 'f' is changed to 'female'

# %%
df.Gender = [x.lower()[0].replace('m','male').replace('f','female') for x in df.Gender]
print(df.Gender)
# Out:
# ID
# 8      female
# 31     female
# 56       male
# 140    female
# 148      male
# 185    female
# 176    female
# 227    female
# 233    female
# 279      male
# 318    female
# 378    female
# 505    female
# 506    female
# 570    female
# 619    female
# 35     female
# 55       male
# 106    female
# 139      male
# 141    female
# 166    female
# 274      male
# 286    female
# 394    female
# 518    female
# 580    female
# Name: Gender, dtype: object
# /Users/Neuromancer/anaconda/envs/myenv3/lib/python3.4/site-packages/pandas/core/generic.py:2005: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
df.Hearing = [x.lower()[0].replace('n','no').replace('y','yes') for x in df.Hearing]
print(df.Hearing)
# Out:
# ID
# 8      no
# 31     no
# 56     no
# 140    no
# 148    no
# 185    no
# 176    no
# 227    no
# 233    no
# 279    no
# 318    no
# 378    no
# 505    no
# 506    no
# 570    no
# 619    no
# 35     no
# 55     no
# 106    no
# 139    no
# 141    no
# 166    no
# 274    no
# 286    no
# 394    no
# 518    no
# 580    no
# Name: Hearing, dtype: object
# /Users/Neuromancer/anaconda/envs/myenv3/lib/python3.4/site-packages/pandas/core/generic.py:2005: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
df.Medication = [x.lower()[0].replace('n','no').replace('y','yes') for x in df.Medication]
print(df.Medication)
# Out:
# ID
# 8       no
# 31      no
# 56     yes
# 140     no
# 148     no
# 185     no
# 176    yes
# 227    yes
# 233     no
# 279     no
# 318     no
# 378    yes
# 505     no
# 506    yes
# 570     no
# 619     no
# 35      no
# 55      no
# 106    yes
# 139     no
# 141     no
# 166     no
# 274     no
# 286     no
# 394     no
# 518     no
# 580     no
# Name: Medication, dtype: object
# /Users/Neuromancer/anaconda/envs/myenv3/lib/python3.4/site-packages/pandas/core/generic.py:2005: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %% [markdown]
# This column was a bit more challenging because of the NaN's. The list comprehension doesn't cope with the NaN's and rather than write out a whole loop with clauses to handle it, I decided to just select out the non-NaN values for the list comprehension __df['General_Fam_history?'].dropna()__ and replace the non-NaN values in the column __pd.notnull(df['General_Fam_history?'])__.
#
# ---
#
# df['General_Fam_history?'][pd.notnull(df['General_Fam_history?'])] = [x.lower()[0].replace('n','no').replace('y','yes') for x in df['General_Fam_history?'].dropna()]

# %%
df['General_Fam_history?'][pd.notnull(df['General_Fam_history?'])] = [x.lower()[0].replace('n','no').replace('y','yes') for x in df['General_Fam_history?'].dropna()]
# Out:
# /Users/Neuromancer/anaconda/envs/myenv3/lib/python3.4/site-packages/IPython/kernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
df
# Out:
#      Age  Gender  Years_Educ          Education_Comp  \
# ID
# 8     26  female         6.0           Undergraduate
# 31    26  female         3.5          Secondary/TAFE
# 56    27    male        13.0           Post Graduate
# 140   19  female         2.0               Secondary
# 148   19    male         2.0           Undergraduate
# 185   18  female         3.0               Secondary
# 176   18  female         3.0               Secondary
# 227   19  female         3.0               Secondary
# 233   18  female         3.0               Secondary
# 279   33    male        20.0           Post Graduate
# 318   20  female         3.0               Secondary
# 378   19  female         3.0               Secondary
# 505   27  female         7.0           Undergraduate
# 506   25  female        20.0           Undergraduate
# 570   26  female        17.0                Graduate
# 619   30  female         7.0           Undergraduate
# 35    37  female        15.0                Graduate
# 55    20    male         4.0               Secondary
# 106   18  female        14.0               Secondary
# 139   18    male         3.0               Secondary
# 141   18  female         2.5               Secondary
# 166   19  female         3.0               Secondary
# 274   27    male        12.0                Graduate
# 286   18  female         2.0               Secondary
# 394   18  female         3.0               Secondary
# 518   22  female         7.0               Secondary
# 580   29  female         9.0  Undergraduate, Honours
#
#                        Study_disapline                        Occupation  \
# ID
# 8                Nutrition & Dietetics                 Dietician/Teacher
# 31               International studies                       Electrician
# 56                    Medical Research                   Research Fellow
# 140                 Psych and Forensic                           Student
# 148                         psychology                           student
# 185                         Psychology                           Butcher
# 176  Business (advertising)/Psychology                           Student
# 227                Forensic Psychology       Student & part time watress
# 233                         Psychology                        unemployed
# 279                   hearing research                       audiologist
# 318        Psychology Forensic Science                           Student
# 378                         Psychology                      Receptionist
# 505                     neuro science                           Student
# 506                         Psychology                           Student
# 570                         psychology                           student
# 619        Human Resources & Education               HR Projects Officer
# 35                Sensory neuroscience                        Researcher
# 55   International & Political studies                           Student
# 106                         Philosophy                           Student
# 139                Science(Psychology)                            Studen
# 141                 Psych and Forensic                           Student
# 166                        Psychology                           Student
# 274                                 IT  PhD Student / Software Developer
# 286   Criminology and Forensic Science                           Student
# 394        Psychology/forensic science                           cinemas
# 518                   Psychophysiology                 Medical Scientist
# 580             Cognitive Neuroscience              Student / Researcher
#
#     Hearing Medication                              Unnamed:_9  \
# ID
# 8        no         no                                     NaN
# 31       no         no                                     NaN
# 56       no        yes                                  zertex
# 140      no         no                                     NaN
# 148      no         no                                     NaN
# 185      no         no                                     NaN
# 176      no        yes  The Pill, Ventolin as needed, Seritide
# 227      no        yes                     Pill(Levlin), xyzal
# 233      no         no                                     NaN
# 279      no         no                                     NaN
# 318      no         no                                     NaN
# 378      no        yes                                   Pill
# 505      no         no                                     NaN
# 506      no        yes                           Contraceptive
# 570      no         no                                     NaN
# 619      no         no                                     NaN
# 35       no         no                                     NaN
# 55       no         no                                     NaN
# 106      no        yes                                    Pill
# 139      no         no                                     NaN
# 141      no         no                                     NaN
# 166      no         no                         Pill(Femme tab)
# 274      no         no                                     NaN
# 286      no         no                                     NaN
# 394      no         no                                     NaN
# 518      no         no                                     NaN
# 580      no         no                                     NaN
#
#     General_Fam_history?                                        Unnamed:_11  \
# ID
# 8                    yes      Grandfather had Seasonal Affective Depression
# 31                    no                                                NaN
# 56                    no                                                NaN
# 140                  NaN                                                NaN
# 148                  yes                                      Aunty Anxiety
# 185                  NaN                                                NaN
# 176                  yes                          Schizophrenia, Depression
# 227                   no                                                NaN
# 233                  yes                           Depression, bipolar, ASD
# 279                   no                                                NaN
# 318                   no                                                NaN
# 378                  yes                                         Depression
# 505                  yes                 Depression, Schizophrenia, Anxiety
# 506                   no                                                NaN
# 570                  yes                             Bipolar, schizophrenia
# 619                  yes                                                NaN
# 35                   yes                          Paternal Major Depression
# 55                   yes  Mother's cousin on her father's side was diagn...
# 106                  yes                                       Schizophenia
# 139                  NaN                                                NaN
# 141                  NaN                                                NaN
# 166                  yes                                         Depression
# 274                   no                                                NaN
# 286                  yes                                 Male cousin Autism
# 394                  yes                          Brother is schizophrenic
# 518                   no                                                NaN
# 580                   no                                                NaN
#
#     1st_degree_Family_history  \
# ID
# 8                          No
# 31                        yes
# 56                        No.
# 140                        No
# 148                        No
# 185                        No
# 176                       No.
# 227                        No
# 233                      Yes.
# 279                        No
# 318                        No
# 378                       Yes
# 505                       Yes
# 506                        No
# 570                       Yes
# 619                      Yes.
# 35                       Yes.
# 55                        NaN
# 106                      Yes.
# 139                       yes
# 141                        no
# 166                        No
# 274                        No
# 286                     Check
# 394                       NaN
# 518                       NaN
# 580                       NaN
#
#                                            Diagnosis Personal_History  \
# ID
# 8                                                NaN               No
# 31                              Paternal cyclothymia               No
# 56                                               NaN              NaN
# 140                                              NaN               No
# 148                                              NaN               No
# 185                                              NaN              NA?
# 176                                              NaN               No
# 227                                              NaN               No
# 233                Maternal and Paternal Depression               Yes
# 279                                              NaN               No
# 318                                              NaN              No.
# 378          Maternal Depression, Sibling Depression               No
# 505                 Mother Depression, Schizophrenia               No
# 506                                              NaN               No
# 570                                  Sibling Bipolar               No
# 619  brother ASD as adult, schizophrenia, depression               No
# 35                         Paternal Major Depression              Yes
# 55                                               NaN              NaN
# 106                           Paternal Schizophrenia              Yes
# 139                              Maternal depression              NaN
# 141                                              NaN              NaN
# 166                                              NaN               No
# 274                                              NaN               No
# 286                                              NaN              Yes
# 394                                              NaN              NaN
# 518                                              NaN              NaN
# 580                                              NaN              NaN
#
#                                            Diagnosis.1  \
# ID
# 8                                                  NaN
# 31                                                 NaN
# 56                                                 NaN
# 140                                                NaN
# 148                                                NaN
# 185                                                NaN
# 176                                                NaN
# 227                                                NaN
# 233                                         Depression
# 279                                                NaN
# 318                                                NaN
# 378                                                NaN
# 505                                                NaN
# 506                                                NaN
# 570                                                NaN
# 619                                                NaN
# 35   Bipolar affective disorder(type 1)with psychot...
# 55                                                 NaN
# 106                                           Anorexia
# 139                                                NaN
# 141                                                NaN
# 166                                                NaN
# 274                                                NaN
# 286                                 Deression, Anxiety
# 394                                                NaN
# 518                                                NaN
# 580                                                NaN
#
#                  Medicated?  Smoker?  Frequency    Menstruation  \
# ID
# 8                        No       No        NaN               -
# 31                      NaN       No        NaN             NaN
# 56                      NaN       No        NaN             NaN
# 140                     NaN      NaN        NaN             NaN
# 148                     NaN  CONTACT        NaN             NaN
# 185                     NaN      NaN        NaN             NaN
# 176                     NaN       No        NaN         21 days
# 227                     NaN  CONTACT        NaN             NaN
# 233                      No  CONTACT        NaN             NaN
# 279                     NaN       No        NaN             NaN
# 318                     NaN       No        NaN           4days
# 378                     NaN       No        NaN          8 days
# 505                     NaN       No        NaN          1month
# 506                     NaN       No        NaN  Unknown(years)
# 570                     NaN       No        NaN          14days
# 619                     NaN       No        NaN           0days
# 35                      Yes       No        NaN             NaN
# 55                      NaN      NaN        NaN             NaN
# 106                     No        No        NaN           7days
# 139                     NaN      NaN        NaN             NaN
# 141                     NaN      NaN        NaN             NaN
# 166                     NaN       No        NaN          14days
# 274                     NaN       No        NaN             NaN
# 286  Yes(Zoloft sertraline)       No        NaN         5 weeks
# 394                     NaN      NaN        NaN             NaN
# 518                     NaN      NaN        NaN             NaN
# 580                     NaN       No        NaN          5 days
#
#             Contraceptive
# ID
# 8                     NaN
# 31                    NaN
# 56                    NaN
# 140                   NaN
# 148                   NaN
# 185                   NaN
# 176       Yes, Pill (Jaz)
# 227      Yes,Pill(Levlin)
# 233             yes, pill
# 279                   NaN
# 318                    No
# 378           Yes, Levlin
# 505             Yes, Pill
# 506    Yes, Depo Ralovera
# 570                    No
# 619                    No
# 35            Yes, Merina
# 55                    NaN
# 106             yes, pill
# 139                   NaN
# 141                   NaN
# 166  Yes, Pill(femme tab)
# 274                   NaN
# 286                    no
# 394                   NaN
# 518                   NaN
# 580                    No

# %% [markdown]
#
#     As I'm writing all these list comprehensions, it's occuring to me that I should make a function that does it.

# %%
[x.lower()[0].replace('m','male').replace('f','female').replace('n','False').replace('y','True') for x in df.Hearing]
# Out:
# ['False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False',
#  'False']

# %%
str(True)
# Out:
# 'True'

# %%
[str(x).lower() in ['yes','y','1','True'] for x in df.Medication]
# Out:
# [False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False]
